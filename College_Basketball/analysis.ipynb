# %%
import seaborn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Load Concatenated Table into Pandas

# %%
df = pd.read_csv("cbb00.csv")

# %%
df.head(5)
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  year
# 0  ...  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016  20bb
# 1  ...  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015  20bb
# 2  ...  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018  20bb
# 3  ...  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019  20bb
# 4  ...  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017  20bb
#
# [5 rows x 25 columns]

# %%
df = df.drop('year', axis=1)

# %%
df.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean     30.486233    15.990633   103.151320   103.153250     0.494067
# std       3.951584     6.572893     7.264859     6.511989     0.255338
# min       5.000000     0.000000    76.600000    84.000000     0.005000
# 25%      29.000000    11.000000    98.200000    98.400000     0.281300
# 50%      31.000000    16.000000   102.800000   103.200000     0.475600
# 75%      33.000000    21.000000   107.900000   107.800000     0.714250
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000  ...
# mean     49.887823    50.087113    18.696509    18.625092    29.308544  ...
# std       3.078505     2.894967     2.104119     2.241067     4.214131  ...
# ...

# %% [markdown]
# Create a function to get mean values from each year and plot graph

# %%
def avg_stat_year(data,stat):
    # Group data by year and calc mean
    mean_stat = data.groupby('YEAR')[stat].mean()
    # Create Line plot of mean stats over the years
    plt.plot(mean_stat.index,mean_stat.values)
    plt.xlabel('Year')
    plt.ylabel('Average ' + stat)
    plt.title ('Average ' + stat)
    plt.show()

# %% [markdown]
# Lets explore 3 point shooting percentage overtime

# %%
avg_stat_year(df,'3P_O')

# %% [markdown]
# Now lets explore 2 Point shooting percentage overtime

# %%
avg_stat_year(df, '2P_O')
